# %%
# !pip3 install faster-whisper
# Out:
# Collecting faster-whisper
#   Downloading faster_whisper-1.2.1-py3-none-any.whl.metadata (16 kB)
# Collecting ctranslate2<5,>=4.0 (from faster-whisper)
#   Downloading ctranslate2-4.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: huggingface-hub>=0.21 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from faster-whisper) (1.18.0)
# Collecting tokenizers<1,>=0.13 (from faster-whisper)
#   Downloading tokenizers-0.23.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.8 kB)
# Collecting onnxruntime<2,>=1.14 (from faster-whisper)
#   Downloading onnxruntime-1.26.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting av>=11 (from faster-whisper)
#   Downloading av-17.1.0-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from faster-whisper) (4.67.3)
# Requirement already satisfied: setuptools in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from ctranslate2<5,>=4.0->faster-whisper) (80.9.0)
# Requirement already satisfied: numpy in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from ctranslate2<5,>=4.0->faster-whisper) (2.4.6)
# Requirement already satisfied: pyyaml<7,>=5.3 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from ctranslate2<5,>=4.0->faster-whisper) (6.0.3)
# Requirement already satisfied: flatbuffers in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from onnxruntime<2,>=1.14->faster-whisper) (25.12.19)
# Requirement already satisfied: packaging in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from onnxruntime<2,>=1.14->faster-whisper) (26.2)
# Requirement already satisfied: protobuf in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from onnxruntime<2,>=1.14->faster-whisper) (6.33.5)
# Requirement already satisfied: click>=8.4.0 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from huggingface-hub>=0.21->faster-whisper) (8.4.0)
# Requirement already satisfied: filelock>=3.10.0 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from huggingface-hub>=0.21->faster-whisper) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from huggingface-hub>=0.21->faster-whisper) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from huggingface-hub>=0.21->faster-whisper) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from huggingface-hub>=0.21->faster-whisper) (0.28.1)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from huggingface-hub>=0.21->faster-whisper) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from huggingface-hub>=0.21->faster-whisper) (4.15.0)
# Requirement already satisfied: anyio in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (4.12.1)
# Requirement already satisfied: certifi in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (1.0.9)
# Requirement already satisfied: idna in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.21->faster-whisper) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.21->faster-whisper) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.21->faster-whisper) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.21->faster-whisper) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.21->faster-whisper) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/joel/miniconda3/envs/aitopics/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.21->faster-whisper) (0.1.2)
# Downloading faster_whisper-1.2.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.8 MB/s  0:00:00 eta 0:00:01
# Downloading ctranslate2-4.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (39.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.5/39.5 MB 6.9 MB/s  0:00:05 eta 0:00:01
# Downloading onnxruntime-1.26.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 12.3 MB/s  0:00:01 eta 0:00:01
# Downloading tokenizers-0.23.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 12.7 MB/s  0:00:00 eta 0:00:01
# Downloading av-17.1.0-cp311-abi3-manylinux_2_28_x86_64.whl (35.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.4/35.4 MB 11.8 MB/s  0:00:02 eta 0:00:01
# Installing collected packages: onnxruntime, ctranslate2, av, tokenizers, faster-whisper
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [faster-whisper]m [tokenizers]]
# Successfully installed av-17.1.0 ctranslate2-4.8.0 faster-whisper-1.2.1 onnxruntime-1.26.0 tokenizers-0.23.1

# %%
from faster_whisper import WhisperModel

audio_path = "output_audio_open_chord.wav"

model = WhisperModel(
    "base",
    device="cpu",
    compute_type="int8"
)

segments, info = model.transcribe(
    audio_path,
    beam_size=5
)

print("Detected language:", info.language)
print("Language probability:", info.language_probability)

transcript_segments = []

for segment in segments:
    transcript_segments.append({
        "start": segment.start,
        "end": segment.end,
        "text": segment.text.strip()
    })

    print(f"{segment.start:.2f}s - {segment.end:.2f}s: {segment.text}")
# Out:
# Detected language: en
# Language probability: 0.4825531840324402
# 0.00s - 2.00s:  You

# %%
full_transcript = " ".join(
    segment["text"] for segment in transcript_segments
)

print(full_transcript)
# Out:
# You

# %%
speech_metadata = {
    "description": full_transcript,
    "language": info.language,
    "language_probability": info.language_probability,
    "segments": transcript_segments
}

speech_metadata
# Out:
# {'description': 'You',
#  'language': 'en',
#  'language_probability': 0.4825531840324402,
#  'segments': [{'start': 0.0, 'end': 2.0, 'text': 'You'}]}

# %%
model = WhisperModel("base", device="cpu", compute_type="int8")


segments,info = model.transcribe("output_audio_open_chord.wav")


for segment in segments:
    print(segment.text)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#  You
